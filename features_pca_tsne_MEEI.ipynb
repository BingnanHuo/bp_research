# %%
# %matplotlib widget

import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ProcessResults import *
from DatasetTester import *
from GetLandmarks import GetLandmarks 
#from LandmarkTester_alt import LandmarkTester

from landmark_utils import vis_landmarks, compare_landmarks
from vis_utils import *


import cv2
import numpy as np
import time
import timeit
from pathlib import Path
import csv
import pickle

from sklearn.neural_network import MLPClassifier
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler, PowerTransformer, QuantileTransformer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from mpl_toolkits.mplot3d import Axes3D

from scipy import linalg
import seaborn as sns

# %%
MEEI_path = Path('./MEEI_Standard_Set')
pat_info = pd.read_excel(MEEI_path/"pat_info.xlsx", sheet_name='Sheet1')

# %%
pat_info = pd.read_pickle('MEEI_pat_info.pkl')

with open('all_pats_processed_data.pickle','rb') as f:
    loaded_pats = pickle.load(f)

# %%
pat_info
# Out:
#       Category Sub-category   #   Side  Gender  Age  \
# 0      Flaccid     Complete   1   Left    Male   54
# 1      Flaccid     Complete   2  Right  Female   16
# 2      Flaccid     Complete   3  Right    Male   38
# 3      Flaccid     Complete   4   Left  Female   31
# 4      Flaccid     Complete   5   Left  Female   52
# 5      Flaccid         Mild   1   Left    Male   72
# 6      Flaccid         Mild   2  Right  Female   55
# 7      Flaccid         Mild   3   Left    Male   75
# 8      Flaccid     Moderate   1   Left    Male   51
# 9      Flaccid     Moderate   3   Left  Female   62
# 10     Flaccid     Moderate   4  Right    Male   21
# 11     Flaccid     Moderate   5  Right  Female   64
# 12     Flaccid   NearNormal   1   Left  Female   39
# 13     Flaccid   NearNormal   2  Right  Female   53
# 14     Flaccid   NearNormal   4   Left    Male   30
# 15     Flaccid   NearNormal   5  Right    Male   47
# 16     Flaccid       Severe   1   Left    Male   46
# 17     Flaccid       Severe   2   Left  Female   58
# 18     Flaccid       Severe   3  Right  Female   28
# 19     Flaccid       Severe   5   Left  Female   50
# 20      Normal          NaN   1    NaN    Male   75
# 21      Normal          NaN   2    NaN    Male   36
# 22      Normal          NaN   3    NaN    Male   29
# 23      Normal          NaN   4    NaN  Female   24
# 24      Normal          NaN   5    NaN  Female   35
# 25      Normal          NaN   6    NaN  Female   33
# 26      Normal          NaN   7    NaN  Female   48
# 27      Normal          NaN   8    NaN    Male   33
# 28      Normal          NaN   9    NaN  Female   92
# 29      Normal          NaN  10    NaN    Male   27
# 30  Synkinetic     Complete   1  Right  Female   61
# 31  Synkinetic     Complete   2   Left  Female   68
# 32  Synkinetic     Complete   3  Right  Female   36
# 33  Synkinetic     Complete   4   Left    Male   55
# 34  Synkinetic         Mild   1   Left    Male   50
# 35  Synkinetic         Mild   2  Right    Male   77
# 36  Synkinetic         Mild   3  Right  Female   77
# 37  Synkinetic         Mild   5   Left  Female   53
# 38  Synkinetic     Moderate   1  Right  Female   59
# 39  Synkinetic     Moderate   2  Right  Female   60
# 40  Synkinetic     Moderate   3   Left  Female   58
# 41  Synkinetic     Moderate   5   Left    Male   42
# 42  Synkinetic   NearNormal   1  Right  Female   58
# 43  Synkinetic   NearNormal   2   Left  Female   46
# 44  Synkinetic   NearNormal   3  Right  Female   48
# 45  Synkinetic   NearNormal   4  Right    Male   35
# 46  Synkinetic   NearNormal   5   Left    Male   40
# 47  Synkinetic       Severe   1  Right  Female   28
# 48  Synkinetic       Severe   2   Left  Female   30
# 49  Synkinetic       Severe   3  Right    Male   50
# 50  Synkinetic       Severe   4  Right    Male   76
#
#                                                  Path  HB_scale
# 0   MEEI_Standard_Set/Flaccid/CompleteFlaccid/Comp...         6
# 1   MEEI_Standard_Set/Flaccid/CompleteFlaccid/Comp...         6
# 2   MEEI_Standard_Set/Flaccid/CompleteFlaccid/Comp...         6
# 3   MEEI_Standard_Set/Flaccid/CompleteFlaccid/Comp...         6
# 4   MEEI_Standard_Set/Flaccid/CompleteFlaccid/Comp...         6
# 5   MEEI_Standard_Set/Flaccid/MildFlaccid/MildFlac...         3
# 6   MEEI_Standard_Set/Flaccid/MildFlaccid/MildFlac...         3
# 7   MEEI_Standard_Set/Flaccid/MildFlaccid/MildFlac...         3
# 8   MEEI_Standard_Set/Flaccid/ModerateFlaccid/Mode...         4
# 9   MEEI_Standard_Set/Flaccid/ModerateFlaccid/Mode...         4
# 10  MEEI_Standard_Set/Flaccid/ModerateFlaccid/Mode...         4
# 11  MEEI_Standard_Set/Flaccid/ModerateFlaccid/Mode...         4
# 12  MEEI_Standard_Set/Flaccid/NearNormalFlaccid/Ne...         2
# 13  MEEI_Standard_Set/Flaccid/NearNormalFlaccid/Ne...         2
# 14  MEEI_Standard_Set/Flaccid/NearNormalFlaccid/Ne...         2
# 15  MEEI_Standard_Set/Flaccid/NearNormalFlaccid/Ne...         2
# 16  MEEI_Standard_Set/Flaccid/SevereFlaccid/Severe...         5
# 17  MEEI_Standard_Set/Flaccid/SevereFlaccid/Severe...         5
# 18  MEEI_Standard_Set/Flaccid/SevereFlaccid/Severe...         5
# 19  MEEI_Standard_Set/Flaccid/SevereFlaccid/Severe...         5
# 20                   MEEI_Standard_Set/Normal/Normal1         1
# 21                   MEEI_Standard_Set/Normal/Normal2         1
# 22                   MEEI_Standard_Set/Normal/Normal3         1
# 23                   MEEI_Standard_Set/Normal/Normal4         1
# 24                   MEEI_Standard_Set/Normal/Normal5         1
# 25                   MEEI_Standard_Set/Normal/Normal6         1
# 26                   MEEI_Standard_Set/Normal/Normal7         1
# 27                   MEEI_Standard_Set/Normal/Normal8         1
# 28                   MEEI_Standard_Set/Normal/Normal9         1
# 29                  MEEI_Standard_Set/Normal/Normal10         1
# 30  MEEI_Standard_Set/Synkinetic/CompleteSynkineti...         6
# 31  MEEI_Standard_Set/Synkinetic/CompleteSynkineti...         6
# 32  MEEI_Standard_Set/Synkinetic/CompleteSynkineti...         6
# 33  MEEI_Standard_Set/Synkinetic/CompleteSynkineti...         6
# 34  MEEI_Standard_Set/Synkinetic/MildSynkinetic/Mi...         3
# 35  MEEI_Standard_Set/Synkinetic/MildSynkinetic/Mi...         3
# 36  MEEI_Standard_Set/Synkinetic/MildSynkinetic/Mi...         3
# 37  MEEI_Standard_Set/Synkinetic/MildSynkinetic/Mi...         3
# 38  MEEI_Standard_Set/Synkinetic/ModerateSynkineti...         4
# 39  MEEI_Standard_Set/Synkinetic/ModerateSynkineti...         4
# 40  MEEI_Standard_Set/Synkinetic/ModerateSynkineti...         4
# 41  MEEI_Standard_Set/Synkinetic/ModerateSynkineti...         4
# 42  MEEI_Standard_Set/Synkinetic/NearNormalSynkine...         2
# 43  MEEI_Standard_Set/Synkinetic/NearNormalSynkine...         2
# 44  MEEI_Standard_Set/Synkinetic/NearNormalSynkine...         2
# 45  MEEI_Standard_Set/Synkinetic/NearNormalSynkine...         2
# 46  MEEI_Standard_Set/Synkinetic/NearNormalSynkine...         2
# 47  MEEI_Standard_Set/Synkinetic/SevereSynkinetic/...         5
# 48  MEEI_Standard_Set/Synkinetic/SevereSynkinetic/...         5
# 49  MEEI_Standard_Set/Synkinetic/SevereSynkinetic/...         5
# 50  MEEI_Standard_Set/Synkinetic/SevereSynkinetic/...         5

# %%
# x - choose one
all_ids = loaded_pats[0]
all_imgs = loaded_pats[1]
all_lms = loaded_pats[2]
all_features = loaded_pats[3]

# y
all_hb = loaded_pats[4]

# %%
# Find NaN and Inf values
bad_indices = np.where(np.isnan(all_features).sum(axis=1) > 0)[0]
bad_indices = np.append(bad_indices, np.where(np.isinf(all_features).sum(axis=1) > 0)[0])
bad_indices.sort()
bad_indices
# Out:
# array([], dtype=int64)

# %%
# drop bad indices 
# x
all_ids = np.delete(all_ids, bad_indices, axis=0)
all_imgs = np.delete(all_imgs, bad_indices, axis=0)
all_lms = np.delete(all_lms, bad_indices, axis=0)
all_features = np.delete(all_features, bad_indices, axis=0)

# y
all_hb = np.delete(all_hb, bad_indices, axis=0)

all_features.shape, all_hb.shape
# Out:
# ((408, 29), (408,))

# %%
fea_cols = ['f'+str(i) for i in range(0, 29)]
plot_df = pd.DataFrame(all_features, columns = fea_cols)
plot_df['hb'] = all_hb
plot_df['label'] = plot_df['hb'].apply(lambda i: str(i))

# %%
plot_df[0:3]
# Out:
#          f0        f1         f2        f3        f4        f5        f6  \
# 0  1.645194  2.809980  12.804038  1.051468  0.028722  0.049083  0.227269
# 1  0.246923  0.902054   9.176017  1.018437  0.004310  0.015745  0.161535
# 2  1.790182  2.934977   8.810501  1.046135  0.031255  0.051270  0.154996
#
#          f7        f8        f9  ...       f21        f22        f23  \
# 0  2.569246  1.085103  1.056966  ...  1.708418  11.120797 -18.251646
# 1  1.434833  1.038511  1.124336  ...  1.411155   4.451960  -3.935614
# 2  2.976652  1.081688  1.062997  ...  1.599003   9.270165 -21.161253
#
#         f24       f25       f26       f27       f28  hb  label
# 0  1.096649  0.762102  0.713114  0.290126  0.124687   6      6
# 1  1.008166  0.679881  0.633601  0.290066  0.122279   6      6
# 2  1.180876  0.736106  0.681453  0.299673  0.124621   6      6
#
# [3 rows x 31 columns]

# %%
pca = PCA(n_components=5)
pca_result = pca.fit_transform(plot_df[fea_cols].values)

plot_df['pca-one'] = pca_result[:,0]
plot_df['pca-two'] = pca_result[:,1] 
plot_df['pca-three'] = pca_result[:,2]
plot_df['pca-four'] = pca_result[:,3]
plot_df['pca-five'] = pca_result[:,4]

print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
# Out:
# Explained variation per principal component: [0.42113987 0.285466   0.18336478 0.05356278 0.02900617]

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue="label",
    palette=sns.color_palette("hls", 6),
    data=plot_df[:],
    legend="full",
    alpha=0.9)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
time_start = time.time()
tsne = TSNE(n_components=3, verbose=1, perplexity=40, n_iter=1000)
tsne_results = tsne.fit_transform(plot_df[fea_cols].values)

print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 408 samples in 0.000s...
# [t-SNE] Computed neighbors for 408 samples in 0.058s...
# [t-SNE] Computed conditional probabilities for sample 408 / 408
# [t-SNE] Mean sigma: 1.946278
# [t-SNE] KL divergence after 150 iterations with early exaggeration: 55.636909
# [t-SNE] KL divergence after 800 iterations: 0.468211
# t-SNE done! Time elapsed: 4.220996856689453 seconds

# %%
plot_df['tsne-2d-one'] = tsne_results[:,0]
plot_df['tsne-2d-two'] = tsne_results[:,1]

plt.figure(figsize=(7,5))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="label",
    palette=sns.color_palette("hls", 10),
    data=plot_df,
    legend="full",
    alpha=0.9)
plt.show()
# Out:
# /tmp/ipykernel_530508/1437045841.py:5: UserWarning: The palette list has more values (10) than needed (6), which may not be intended.
#   sns.scatterplot(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pca_10 = PCA(n_components=10)
pca_result_10 = pca_10.fit_transform(plot_df[fea_cols].values)

print('Cumulative explained variation for 50 principal components: {}'.format(np.sum(pca_10.explained_variance_ratio_)))
# Out:
# Cumulative explained variation for 50 principal components: 0.9987983107566833

# %%
time_start = time.time()

tsne = TSNE(n_components=2, verbose=0, perplexity=40, n_iter=300)
tsne_pca_results = tsne.fit_transform(pca_result_10)

print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# t-SNE done! Time elapsed: 1.0312540531158447 seconds

# %%
plot_df['tsne-pca50-one'] = tsne_pca_results[:,0]
plot_df['tsne-pca50-two'] = tsne_pca_results[:,1]
ax3 = plt.figure()
sns.scatterplot(
    x="tsne-pca50-one", y="tsne-pca50-two",
    hue="label",
    palette=sns.color_palette("hls", 10),
    data=plot_df,
    legend="full",
    alpha=0.9)
plt.show()
# Out:
# /tmp/ipykernel_530508/2289151534.py:4: UserWarning: The palette list has more values (10) than needed (6), which may not be intended.
#   sns.scatterplot(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#sns.boxplot(x = plot_df, hue = plot_df['hb'])
plt.figure()
#plt.boxplot(plot_df)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def feature_plot(df, which_feature, group_by):
    sns.displot(df, x=which_feature, hue=group_by, element="step")

# %%
#for i in range(0, 29):
#    feature_plot(plot_df, 'f'+str(i), 'hb')

# %% [markdown]
# ### Now try transformations on the data

# %%
scaler = StandardScaler() # standardize features by removing the mean and scaling to unit variance
#scaler = MinMaxScaler() # scale features to lie between 0 and 1
#scaler = PowerTransformer() # apply a power transform featurewise to make data more Gaussian-like
#scaler = QuantileTransformer(output_distribution='normal') # transform features using quantiles information

all_features_scaled = scaler.fit_transform(all_features)
plot_df_scaled = pd.DataFrame(all_features_scaled, columns = ['f'+str(i) for i in range(0, 29)])
plot_df_scaled['hb'] = all_hb
#plot_df.shape, plot_df_scaled.shape
plot_df_scaled['sum'] = plot_df_scaled[['f'+str(i) for i in range(0, 29)]].sum(axis=1)
plot_df_scaled[0:5]
# Out:
#          f0        f1        f2        f3        f4        f5        f6  \
# 0  0.788669  0.714530  2.446054  0.965402  0.787717  0.711597  2.456178
# 1 -0.872513 -0.480522  1.428347 -0.241866 -0.871889 -0.480156  1.417740
# 2  0.960919  0.792824  1.325815  0.770472  0.959903  0.789782  1.314434
# 3 -1.126220 -0.430071  1.433920 -0.247744 -1.125275 -0.429888  1.423360
# 4  1.038618  1.343192  2.142361  1.070897  1.037581  1.339921  2.143559
#
#          f7        f8        f9  ...       f21       f22       f23       f24  \
# 0  2.351332  1.575987 -0.508973  ...  0.901177  3.379100 -3.820645  1.547563
# 1  0.822258  0.108196  0.414976  ... -0.460950  0.762041 -0.731984 -0.804107
# 2  2.900476  1.468403 -0.426258  ...  0.399815  2.652855 -4.448388  3.786090
# 3 -0.113153  0.619490 -0.451998  ...  3.905793  1.870380 -2.129643 -0.048409
# 4  2.763428  1.286175  0.094476  ...  0.328938  3.138191 -3.740748  2.324289
#
#         f25       f26       f27       f28  hb        sum
# 0 -0.475142 -0.664485  0.312672  0.380668   6  31.248367
# 1 -1.625250 -1.745450  0.311004  0.282644   6  -2.796999
# 2 -0.838766 -1.094908  0.581807  0.377956   6  25.547846
# 3 -0.795492 -0.932834  0.992754 -1.747401   6  10.837042
# 4 -0.771391 -1.066314  0.643293  0.823624   6  32.616245
#
# [5 rows x 31 columns]

# %%
scaler1 = StandardScaler() # standardize features by removing the mean and scaling to unit variance
scaler2 = MinMaxScaler() # scale features to lie between 0 and 1
scaler3 = PowerTransformer() # apply a power transform featurewise to make data more Gaussian-like
scaler4 = QuantileTransformer(output_distribution='normal') # transform features using quantiles information

scaled1 = scaler1.fit_transform(all_features)
scaled2 = scaler2.fit_transform(all_features)
scaled3 = scaler3.fit_transform(all_features)
scaled4 = scaler4.fit_transform(all_features)
# Out:
# /opt/anaconda/envs/bp/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:2623: UserWarning: n_quantiles (1000) is greater than the total number of samples (408). n_quantiles is set to n_samples.
#   warnings.warn(

# %%
#for i in range(0, 29):
#    feature_plot(plot_df_scaled, 'f'+str(i), 'hb')

# %%
plt.figure()
sns.boxplot(scaled1)
plt.show()

plt.figure()
sns.boxplot(scaled2)
plt.show()

plt.figure()
sns.boxplot(scaled3)
plt.show()

plt.figure()
sns.boxplot(scaled4)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
#sns.histplot(plot_df_scaled)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_df_scaled.plot.density()
# Out:
# <AxesSubplot: ylabel='Density'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_df_scaled.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'f0'}>,
#         <AxesSubplot: title={'center': 'f1'}>,
#         <AxesSubplot: title={'center': 'f2'}>,
#         <AxesSubplot: title={'center': 'f3'}>,
#         <AxesSubplot: title={'center': 'f4'}>,
#         <AxesSubplot: title={'center': 'f5'}>],
#        [<AxesSubplot: title={'center': 'f6'}>,
#         <AxesSubplot: title={'center': 'f7'}>,
#         <AxesSubplot: title={'center': 'f8'}>,
#         <AxesSubplot: title={'center': 'f9'}>,
#         <AxesSubplot: title={'center': 'f10'}>,
#         <AxesSubplot: title={'center': 'f11'}>],
#        [<AxesSubplot: title={'center': 'f12'}>,
#         <AxesSubplot: title={'center': 'f13'}>,
#         <AxesSubplot: title={'center': 'f14'}>,
#         <AxesSubplot: title={'center': 'f15'}>,
#         <AxesSubplot: title={'center': 'f16'}>,
#         <AxesSubplot: title={'center': 'f17'}>],
#        [<AxesSubplot: title={'center': 'f18'}>,
#         <AxesSubplot: title={'center': 'f19'}>,
#         <AxesSubplot: title={'center': 'f20'}>,
#         <AxesSubplot: title={'center': 'f21'}>,
#         <AxesSubplot: title={'center': 'f22'}>,
#         <AxesSubplot: title={'center': 'f23'}>],
#        [<AxesSubplot: title={'center': 'f24'}>,
#         <AxesSubplot: title={'center': 'f25'}>,
#         <AxesSubplot: title={'center': 'f26'}>,
#         <AxesSubplot: title={'center': 'f27'}>,
#         <AxesSubplot: title={'center': 'f28'}>,
#         <AxesSubplot: title={'center': 'hb'}>],
#        [<AxesSubplot: title={'center': 'sum'}>, <AxesSubplot: >,
#         <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >,
#         <AxesSubplot: >]], dtype=object)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_df = plot_df_scaled
plot_df['label'] = plot_df['hb'].apply(lambda i: str(i))

pca = PCA(n_components=5)
pca_result = pca.fit_transform(plot_df[fea_cols].values)

plot_df['pca-one'] = pca_result[:,0]
plot_df['pca-two'] = pca_result[:,1] 
plot_df['pca-three'] = pca_result[:,2]
plot_df['pca-four'] = pca_result[:,3]
plot_df['pca-five'] = pca_result[:,4]

print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
# Out:
# Explained variation per principal component: [0.21413946 0.15286858 0.13256314 0.0758606  0.05715659]

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue="label",
    palette=sns.color_palette("hls", 6),
    data=plot_df[:],
    legend="full",
    alpha=0.9)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=1)
tsne_results = tsne.fit_transform(plot_df[fea_cols].values)

print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 408 samples in 0.000s...
# [t-SNE] Computed neighbors for 408 samples in 0.007s...
# [t-SNE] Computed conditional probabilities for sample 408 / 408
# [t-SNE] Mean sigma: 1.862330
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 58.063179
# [t-SNE] KL divergence after 1000 iterations: 0.930123
# t-SNE done! Time elapsed: 2.283167839050293 seconds

# %%
plot_df['tsne-2d-one'] = tsne_results[:,0]
plot_df['tsne-2d-two'] = tsne_results[:,1]

plt.figure(figsize=(7,5))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="label",
    palette=sns.color_palette("hls"),
    data=plot_df,
    legend="full",
    alpha=0.9)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pca_10 = PCA(n_components=20)
pca_result_10 = pca_10.fit_transform(plot_df[fea_cols].values)

print('Cumulative explained variation for 50 principal components: {}'.format(np.sum(pca_10.explained_variance_ratio_)))
# Out:
# Cumulative explained variation for 50 principal components: 0.9932021498680115

# %%
time_start = time.time()

tsne = TSNE(n_components=2, verbose=1)
tsne_pca_results = tsne.fit_transform(pca_result_10)

print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 408 samples in 0.001s...
# [t-SNE] Computed neighbors for 408 samples in 0.009s...
# [t-SNE] Computed conditional probabilities for sample 408 / 408
# [t-SNE] Mean sigma: 1.855395
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 58.079563
# [t-SNE] KL divergence after 1000 iterations: 0.990221
# t-SNE done! Time elapsed: 2.098567247390747 seconds

# %%
plot_df['tsne-pca50-one'] = tsne_pca_results[:,0]
plot_df['tsne-pca50-two'] = tsne_pca_results[:,1]
ax3 = plt.figure()
sns.scatterplot(
    x="tsne-pca50-one", y="tsne-pca50-two",
    hue="hb",
    palette=sns.color_palette("hls",6),
    data=plot_df,
    legend="full",
    alpha=0.9)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
