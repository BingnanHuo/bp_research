# %%
# %matplotlib widget

#import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.preprocessing import LabelEncoder
import xgboost as xgb
from scipy import linalg
from sklearn.model_selection import train_test_split

# %%
n = 500
A = np.array([np.random.normal(0,2,n), np.random.normal(0,2.5,n)])
A = A.T
B = np.array([np.random.normal(7.5,4,n), np.random.normal(2,1.7,n)])
B = B.T

# %%
A.shape, B.shape
# Out:
# ((500, 2), (500, 2))

# %%
plt.figure(figsize=(6,6))
plt.scatter(A[...,0],A[...,1],color='red')
plt.scatter(B[...,0],B[...,1],color='blue')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x_data = np.concatenate((A,B),axis=0)

# %%
x_data.shape
# Out:
# (1000, 2)

# %%
y_data = np.concatenate((np.ones(n),np.zeros(n)),axis=0)

# %%
(x_train, x_test, y_train, y_test) = train_test_split(x_data, y_data, 
                                                      test_size=0.2, random_state=42)

# %%
#xg_reg = xgb.XGBClassifier(tree_method="gpu_hist", enable_categorical=True, n_estimators=30, max_depth=10)
xg_reg = xgb.XGBClassifier(enable_categorical=True, n_estimators=30, max_depth=10)

# %%
xg_reg.fit(x_train, y_train)
y_pred = xg_reg.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: %2f" % (rmse))
print('Accuracy:', round(accuracy_score(y_test, y_pred), 3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 xg_reg.fit(x_train, y_train)
#       2 y_pred = xg_reg.predict(x_test)
#       3 rmse = np.sqrt(mean_squared_error(y_test, y_pred))
#
# File /opt/anaconda/envs/bp/lib/python3.10/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File /opt/anaconda/envs/bp/lib/python3.10/site-packages/xgboost/sklearn.py:1494, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1485         params["objective"] = "multi:softprob"
#    1486     params["num_class"] = self.n_classes_
#    1488 (
#    1489     model,
#    1490     metric,
#    1491     params,
#    1492     early_stopping_rounds,
#    1493     callbacks,
# -> 1494 ) = self._configure_fit(
#    1495     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1496 )
#    1497 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1498     missing=self.missing,
#    1499     X=X,
#    (...)
#    1513     feature_types=self.feature_types,
#    1514 )
#    1516 self._Booster = train(
#    1517     params,
#    1518     train_dmatrix,
#    (...)
#    1527     callbacks=callbacks,
#    1528 )
#
# File /opt/anaconda/envs/bp/lib/python3.10/site-packages/xgboost/sklearn.py:918, in XGBModel._configure_fit(self, booster, eval_metric, params, early_stopping_rounds, callbacks)
#     916 cat_support = {"gpu_hist", "approx", "hist"}
#     917 if self.enable_categorical and tree_method not in cat_support:
# --> 918     raise ValueError(
#     919         "Experimental support for categorical data is not implemented for"
#     920         " current tree method yet."
#     921     )
#     923 return model, metric, params, early_stopping_rounds, callbacks
#
# ValueError: Experimental support for categorical data is not implemented for current tree method yet.

# %%
bidx = np.where(y_pred!=y_test)[0]
bpts = x_test[bidx]

# %%
plt.figure(figsize=(10,10))
plt.scatter(A[...,0],A[...,1],color='red', alpha=0.5)
plt.scatter(B[...,0],B[...,1],color='blue', alpha=0.5)
plt.scatter(bpts[...,0],bpts[...,1], color='yellow',marker='x')
